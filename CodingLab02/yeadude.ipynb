# %%
import numpy as np
from matplotlib import pyplot as plt
## Your code goes here
from astropy.cosmology import LambdaCDM


a=np.linspace(1000,100000,1000)


I= [(1500/x)*100 for x in a ]
plt.plot(a, I, 'r', label='hola')


plt.title("History of Cosmic Expansion")

plt.xlabel("salaire de la personne")

plt.ylabel("PERCENTAGE of yearly income = 1500$")

plt.legend(loc='upper right')

plt.show()



money = a

percentage = I

for x in range(10)


 XX=X*100
